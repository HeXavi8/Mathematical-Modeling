# %%
import matplotlib.pyplot as plt
import matplotlib.collections as col
import pandas as pd
import random

# %%
center=10
mx=20
artist_pd=pd.read_csv('artist_revolution_2020.csv')
artist_pd
base=30
x,y=[],[]
for i in range(40):
    dis=center+(280-artist_pd.loc[i].score)/base
    rd=random.uniform(0,2*math.pi)
    x.append(center+dis*math.sin(rd))
    y.append(center+dis*math.)

# %%
plt.figure(figsize=(18,18))
# plt.axis('off')
# plt.xlim(-2,2)
plt.xticks([i for i in range(mx+1)])
plt.yticks([])
plt.scatter(10,10)
plt.plot(x,y,'o')
# plt.plot([i for i in range(mx+1)],[center for i in range(mx+1)],marker='x',c='b')
for i in range(1,12):    
    circle1 = plt.Circle((10, 10), i, color='r',alpha=0.06)
    plt.gca().add_patch(circle1)
# plt.colorbar()
# plt.savefig('background.png')
